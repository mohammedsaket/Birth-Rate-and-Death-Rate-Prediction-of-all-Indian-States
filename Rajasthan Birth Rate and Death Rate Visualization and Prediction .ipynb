# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("2-CBR.csv")
df.columns
df.head()
# Out:
#                 State   1971  1972  1973  1974  1975  1976  1977  1978  1979  \
# 0      Andhra Pradesh   31.3  36.7  31.2  32.2  30.1  29.8  27.7  28.6  29.4
# 1   Arunachal Pradesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2               Assam   31.0  27.7  27.6  24.8  23.7  24.0  24.7  23.0  24.0
# 3               Bihar    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        Chhattisgarh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...   2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  ...   16.7  16.8  17.0  16.7  16.6  16.6  16.7  16.3  16.1  15.8
# 1  ...   17.3  15.2  14.9  14.6  14.2  13.9  13.8  13.2  15.3  16.1
# 2  ...   15.5  15.7  15.9  15.8  15.5  15.6  15.4  15.5  15.3  15.0
# 3  ...   22.9  22.5  22.2  22.0  21.7  21.6  21.5  19.9  20.6  21.1
# 4  ...   19.6  19.3  19.0  18.6  18.3  18.0  17.9  18.4  18.3  18.1
#
# [5 rows x 47 columns]

# %%
df=pd.read_csv("2-CBR.csv")
df1 =df.loc[:1, [' State ','2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016']].copy()
arr=['2001', '2002', '2003', '2004','2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
     '2014', '2015', '2016']
for i in arr:
    plt.plot(df[' State '],df[i],label='Square')
plt.xticks(rotation=90)
plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = [20, 5]
plt.figure()

# %%
df=pd.read_csv("2-CBR.csv")
df=df.T
new_header1 = df.iloc[0] 
df = df[1:] 
df.columns = new_header1
df=df.iloc[:,:-1]
df.fillna(0, inplace=True)
#df.head()
df2=pd.read_csv("3-CDR.csv")
df2=df2.T
new_header2 = df2.iloc[0] 
df2 = df2[1:] 
df2.columns = new_header2 
df2=df2.iloc[:,:-1]
df2.fillna(0, inplace=True)

# %%
plt.title("Rajasthan (Birth Rate v/s Death Rate)")
plt.xticks(rotation=90)
plt.plot(df[' Rajasthan '][1:],label='Birth Rate')
plt.plot(df2["Rajasthan"][1:],label='Death Rate')
plt.legend()
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams.update({'font.size': 22})
plt.show()

# %% [markdown]
# # Prediction ( Birth Rate )

# %%
plt.plot(df[' Rajasthan '][1:])
plt.xticks(rotation=90)
plt.title("Rajasthan (Birth Rate)")
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics

    rolmean = timeseries.rolling(window=3).mean()
    rolstd=timeseries.rolling(window=3).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.xticks(rotation=90)
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    timeseries = timeseries.iloc[:,0].values
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
ts = df[" Rajasthan "][1:]
ts.head()
# Out:
# 1972    37.2
# 1973    32.5
# 1974    29.8
# 1975    31.4
# 1976    27.3
# Name:  Rajasthan , dtype: float64

# %%
import numpy as np
ts = df[" Rajasthan "][1:]
ts=ts.to_frame()
ts.index.names = ['Date']
plt.xticks(rotation=90)
ts_log = np.log(ts)
moving_avg = ts_log.rolling(window=3).mean()

ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff)
plt.rcParams['figure.figsize'] = [20, 5]
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.024839
# p-value                         0.000020
# #Lags Used                      2.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64

# %%
ts_log_diff = ts_log - ts_log.shift()
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.732181
# p-value                         0.000073
# #Lags Used                      3.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64

# %% [markdown]
# # Applying ARIMA Model

# %%
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

# %%
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(ts_log, order=(1, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.xticks(rotation=90)
A=results_AR.fittedvalues
B=ts_log_diff.squeeze()
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1071')

# %%
model = ARIMA(ts_log, order=(0, 1, 1))  
results_MA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.xticks(rotation=90)
A=results_MA.fittedvalues
B=ts_log_diff.squeeze()
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1071')

# %%
model = ARIMA(ts_log, order=(1, 1, 1))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
A=results_ARIMA.fittedvalues
B=ts_log_diff.squeeze()
plt.xticks(rotation=90)
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1003')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print (predictions_ARIMA_diff.head())
# Out:
# Date
# 1973   -0.010944
# 1974    0.006719
# 1975    0.016647
# 1976    0.002597
# 1977    0.025091
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print (predictions_ARIMA_diff_cumsum.head())
# Out:
# Date
# 1973   -0.010944
# 1974   -0.004226
# 1975    0.012421
# 1976    0.015018
# 1977    0.040108
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(ts_log.squeeze().iloc[0], index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Date
# 1972    3.616309
# 1973    3.605364
# 1974    3.612083
# 1975    3.628730
# 1976    3.631326
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(ts,label='Original')
plt.xticks(rotation=90)
plt.plot(predictions_ARIMA,label='Prediction')
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts.squeeze())**2)/len(ts)))
# Out:
# Text(0.5,1,'RMSE: 4.0702')

# %%
results_ARIMA.plot_predict(5,55)

# %%
X=int(input("Enter Year(After 2016)="))-2016
print("Predicted Birth Rate of Rajasthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[0][-1]))
print("Lowest Birth Rate of Rajasthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[2][-1][0]))
print("Highest Birth Rate of Rajasthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[2][-1][1]))
# Out:
# Enter Year(After 2016)=2021
# Predicted Birth Rate of Rajasthan in 2021 is 20.249215551417098
# Lowest Birth Rate of Rajasthan in 2021 is 17.854424051732234
# Highest Birth Rate of Rajasthan in 2021 is 22.96521743068889

# %% [markdown]
# # Prediction (Death Rate)

# %%
plt.plot(df2['Rajasthan'][1:])
plt.xticks(rotation=90)
plt.title("Rajasthan (Death Rate)")
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics

    rolmean = timeseries.rolling(window=3).mean()
    rolstd=timeseries.rolling(window=3).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.xticks(rotation=90)
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    timeseries = timeseries.iloc[:,0].values
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
import numpy as np
ts = df.iloc[:,0]
ts=ts.to_frame()
ts.index.names = ['Date']
plt.xticks(rotation=90)
ts_log = np.log(ts)
moving_avg = ts_log.rolling(window=3).mean()

ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff)
plt.rcParams['figure.figsize'] = [20, 5]
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.063700
# p-value                         0.000017
# #Lags Used                      0.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64

# %%
import numpy as np
ts2 = df[" Rajasthan "][1:]
ts2=pd.Series(ts2).convert_objects(convert_numeric=True)
ts2=ts2.to_frame()
ts.index.names = ['Date']
test_stationarity(ts2)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.930741
# p-value                         0.777681
# #Lags Used                      3.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64

# %%
ts2_log = np.log(ts2)
moving_avg2 = ts2_log.rolling(window=3).mean()

ts2_log_moving_avg_diff = ts2_log - moving_avg2
ts2_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts2_log_moving_avg_diff)
plt.rcParams['figure.figsize'] = [20, 5]
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.024839
# p-value                         0.000020
# #Lags Used                      2.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64

# %%
ts2_log_diff = ts2_log - ts2_log.shift()
ts2_log_diff.dropna(inplace=True)
test_stationarity(ts2_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.732181
# p-value                         0.000073
# #Lags Used                      3.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64

# %% [markdown]
# # Applying ARIMA Model

# %%
from statsmodels.tsa.stattools import acf, pacf
lag2_acf = acf(ts2_log_diff, nlags=20)
lag2_pacf = pacf(ts2_log_diff, nlags=20, method='ols')

# %%
plt.subplot(121) 
plt.plot(lag2_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts2_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts2_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag2_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts2_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts2_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA
model2 = ARIMA(ts2_log, order=(2, 1, 0))  
results_AR2 = model2.fit(disp=-1)  
plt.plot(ts2_log_diff)
plt.plot(results_AR2.fittedvalues, color='red')
plt.xticks(rotation=90)
A=results_AR2.fittedvalues
B=ts2_log_diff.squeeze()
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1071')

# %%
model2 = ARIMA(ts2_log, order=(0, 1, 2))  
results_MA2 = model2.fit(disp=-1)  
plt.plot(ts2_log_diff)
plt.plot(results_MA2.fittedvalues, color='red')
plt.xticks(rotation=90)
A=results_MA2.fittedvalues
B=ts2_log_diff.squeeze()
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1071')

# %%
model2 = ARIMA(ts2_log, order=(2, 1, 1))  
results_ARIMA2= model2.fit(disp=-1)  
plt.plot(ts2_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
A=results_ARIMA2.fittedvalues
B=ts2_log_diff.squeeze()
plt.xticks(rotation=90)
plt.title('RSS: %.4f'% sum((A-B)**2))
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'RSS: 0.1071')

# %%
predictions_ARIMA2_diff = pd.Series(results_ARIMA2.fittedvalues, copy=True)
print (predictions_ARIMA2_diff.head())
# Out:
# Date
# 1973   -0.012373
# 1974   -0.008785
# 1975   -0.013374
# 1976   -0.014879
# 1977   -0.006894
# dtype: float64

# %%
predictions_ARIMA2_diff_cumsum = predictions_ARIMA2_diff.cumsum()
print (predictions_ARIMA2_diff_cumsum.head())
# Out:
# Date
# 1973   -0.012373
# 1974   -0.021158
# 1975   -0.034532
# 1976   -0.049412
# 1977   -0.056306
# dtype: float64

# %%
predictions_ARIMA2_log = pd.Series(ts2_log.squeeze().iloc[0], index=ts2_log.index)
predictions_ARIMA2_log = predictions_ARIMA2_log.add(predictions_ARIMA2_diff_cumsum,fill_value=0)
predictions_ARIMA2_log.head()
# Out:
# Date
# 1972    3.616309
# 1973    3.603936
# 1974    3.595151
# 1975    3.581776
# 1976    3.566897
# dtype: float64

# %%
predictions_ARIMA2 = np.exp(predictions_ARIMA2_log)
plt.plot(ts2,label='Original')
plt.xticks(rotation=90)
plt.plot(predictions_ARIMA2,label='Prediction')
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA2-ts2.squeeze())**2)/len(ts2)))
# Out:
# Text(0.5,1,'RMSE: 2.5608')

# %%
results_ARIMA2.plot_predict(1,55)

# %%
X=int(input("Enter Year(After 2016)="))-2016
print("Predicted Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[0][-1]))
print("Lowest Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[2][-1][0]))
print("Highest Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[2][-1][1]))
# Out:
# Enter Year(After 2016)=2021
# Predicted Death Rate of Rajsthan in 2021 is 20.306492043428186
# Lowest Death Rate of Rajsthan in 2021 is 16.395679164461328
# Highest Death Rate of Rajsthan in 2021 is 25.15013955650064

# %%
X=int(input("Enter Year(After 2016)="))-2016
print("Predicted Birth Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[0][-1]))
print("Lowest Birth Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[2][-1][0]))
print("Highest Birth Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA.forecast(steps=X)[2][-1][1]))
print("Predicted Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[0][-1]))
print("Lowest Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[2][-1][0]))
print("Highest Death Rate of Rajsthan in",(X+2016),"is",np.exp(results_ARIMA2.forecast(steps=X)[2][-1][1]))
# Out:
# Enter Year(After 2016)=2023
# Predicted Birth Rate of Rajsthan in 2023 is 19.788834957268524
# Lowest Birth Rate of Rajsthan in 2023 is 17.419167494787306
# Highest Birth Rate of Rajsthan in 2023 is 22.480867072619777
# Predicted Death Rate of Rajsthan in 2023 is 19.810072146662723
# Lowest Death Rate of Rajsthan in 2023 is 15.379787720938332
# Highest Death Rate of Rajsthan in 2023 is 25.516539342198364
